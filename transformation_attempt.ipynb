# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
train_sample_path = "train_sample.csv"
test_sample_path = "test_sample.csv"

# %%
train_sample = pd.read_csv(train_sample_path)
train_sample.head(1)
# Out:
#                     start_point                        end_point time_of_day  \
# 0  West Jakarta (Jakarta Barat)  South Jakarta (Jakarta Selatan)         day
#
#   day_of_week  traffic_condition  event_count  is_holiday vehicle_density  \
# 0      Sunday                NaN            9           1             NaN
#
#   population_density weather  public_transport_availability  \
# 0               high     NaN                              1
#
#    historical_delay_factor  travel_time
# 0                 0.878909    26.907612

# %%
test_sample = pd.read_csv(test_sample_path)

# %%
sns.scatterplot(x=train_sample['historical_delay_factor'], y=train_sample['travel_time'], color='steelblue')
plt.title(f"Scatter Plot of historical_delay_factor vs travel_time")
plt.xlabel("historical_delay_factor")
plt.ylabel("travel_time")
plt.show()

# %%
X_log = np.log1p(train_sample["historical_delay_factor"])
y_log = np.log1p(train_sample["travel_time"])

# %%
sns.scatterplot(x=X_log, y=train_sample["travel_time"])
plt.show()

# %%
sns.scatterplot(x=X_log, y=y_log)
plt.show()

# %%
sns.scatterplot(x=train_sample["historical_delay_factor"], y=y_log)
plt.show()

# %%
X_sqrt = np.sqrt(train_sample["historical_delay_factor"])
y_sqrt = np.sqrt(train_sample["travel_time"])

# %%
sns.scatterplot(x=train_sample["historical_delay_factor"], y=y_sqrt)
plt.show()

# %%
train_sample['historical_delay_factor_sq'] = train_sample['historical_delay_factor'] ** 2
sns.scatterplot(x=train_sample['historical_delay_factor_sq'], y=train_sample['travel_time'])
plt.show()
